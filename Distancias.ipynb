    {'co.cliente': 2330, 'municipio': 'MAUA', 'latitude': -23.66289, 'longitude': -46.48223},
    {'co.cliente': 2331, 'municipio': 'OSASCO', 'latitude': -23.55164, 'longitude': -46.79466},
    {'co.cliente': 2332, 'municipio': 'SAO PAULO', 'latitude': -23.48552, 'longitude': -46.73883},
    {'co.cliente': 2333, 'municipio': 'SAO PAULO', 'latitude': -23.46722, 'longitude': -46.58475},
    {'co.cliente': 2334, 'municipio': 'SANTANA DE PARNAIBA', 'latitude': -23.46668, 'longitude': -46.84622},
    {'co.cliente': 2335, 'municipio': 'SANTANA DE PARNAIBA', 'latitude': -23.46236, 'longitude': -46.87601},
    {'co.cliente': 2336, 'municipio': 'SAO CARLOS', 'latitude': -22.0445, 'longitude': -47.88998},
    {'co.cliente': 2337, 'municipio': 'SAO CARLOS', 'latitude': -22.02384, 'longitude': -47.88021},
    {'co.cliente': 2338, 'municipio': 'SAO CARLOS', 'latitude': -22.03848, 'longitude': -47.86018},
    {'co.cliente': 2339, 'municipio': 'TAUBATE', 'latitude': -23.01733, 'longitude': -45.55106},
    {'co.cliente': 2340, 'municipio': 'TAUBATE', 'latitude': -22.99756, 'longitude': -45.54006},
    {'co.cliente': 2341, 'municipio': 'CACAPAVA', 'latitude': -23.07223, 'longitude': -45.71227},
    {'co.cliente': 2342, 'municipio': 'CACAPAVA', 'latitude': -23.11919, 'longitude': -45.71347},
    {'co.cliente': 2343, 'municipio': 'PINDAMONHANGABA', 'latitude': -22.95467, 'longitude': -45.49489},
    {'co.cliente': 2344, 'municipio': 'SOROCABA', 'latitude': -23.46587, 'longitude': -47.49623},
    {'co.cliente': 2345, 'municipio': 'SOROCABA', 'latitude': -23.49563, 'longitude': -47.51121},
    {'co.cliente': 2346, 'municipio': 'SOROCABA', 'latitude': -23.48649, 'longitude': -47.47117},
    {'co.cliente': 2347, 'municipio': 'RIBEIRAO PRETO', 'latitude': -21.19498, 'longitude': -47.75589},
    {'co.cliente': 2348, 'municipio': 'RIBEIRAO PRETO', 'latitude': -21.14118, 'longitude': -47.80482},
    {'co.cliente': 2349, 'municipio': 'RIBEIRAO PRETO', 'latitude': -21.17516, 'longitude': -47.79455},
    {'co.cliente': 2350, 'municipio': 'BAURU', 'latitude': -22.3121, 'longitude': -49.05746},
    {'co.cliente': 2351, 'municipio': 'BAURU', 'latitude': -22.31628, 'longitude': -49.06815}
]

data = pd.DataFrame.from_dict(clientes)
data.head()

#DISTANCIAS FABRICAS:
cod_fabrica1 = "3423909"
lat_fabrica1 = -23.25178418
long_fabrica1 = -47.3439079

cod_fabrica2 = "3403208"
lat_fabrica2 = -21.82093539
long_fabrica2 = -48.17232722

cod_fabrica3 = "3424402"
lat_fabrica3 = -23.28713588
long_fabrica3 = -45.9849763


from geopy.distance import geodesic
import requests

#FÁBRICA 01:
for index, row in data.iterrows():
    coordenadas_fabrica1 = (lat_fabrica1, long_fabrica1)
    coordenadas_clientes1 = (row['latitude'], row['longitude'])
    distancia1 = round(geodesic(coordenadas_fabrica1, coordenadas_clientes1).kilometers,2)
    print(f"Distância da fabrica 01 para {row['co.cliente']}: {distancia1} km")
#FÁBRICA 02:
for index, row in data.iterrows():
    coordenadas_fabrica2 = (lat_fabrica2, long_fabrica2)
    coordenadas_clientes2 = (row['latitude'], row['longitude'])
    distancia2 = round(geodesic(coordenadas_fabrica2, coordenadas_clientes2).kilometers,2)
    print(f"Distância da fabrica 02 para {row['co.cliente']}: {distancia2} km")
#FÁBRICA 03:
for index, row in data.iterrows():
    coordenadas_fabrica3 = (lat_fabrica3, long_fabrica3)
    coordenadas_clientes3 = (row['latitude'], row['longitude'])
    distancia3 = round(geodesic(coordenadas_fabrica3, coordenadas_clientes3).kilometers,2)
    print(f"Distância da fabrica 03 para {row['co.cliente']}: {distancia3} km")


def calculate_road_distance(origin, destination):
    url = "http://dev.virtualearth.net/REST/v1/Routes/DistanceMatrix"
    params = {
        "origins": f"{origin[0]},{origin[1]}",
        "destinations": f"{destination[0]},{destination[1]}",
        "travelMode": "driving",
        "key": "AmQ4bukp9WLfN9GqIntfn9pJugIvSSSfM7OxMxws5Up0F88YqlsXAA6IAPk6_vdI"
    }
    resposta = requests.get(url, params=params)
    data = resposta.json()
    if "resourceSets" in data and data["resourceSets"]:
        resultado = data["resourceSets"][0]["resources"]
        if resultado:
            return resultado[0]["results"][0]["travelDistance"]
    return None
#DISTANCIA REAL FÁBRICA 01:
for index, row in data.iterrows():
    coordenadas_clientes1 = (row['latitude'], row['longitude'])
    distancia_real1 = round(calculate_road_distance((lat_fabrica1, long_fabrica1), coordenadas_clientes1),2)
    if distancia_real1 is not None:
        print(f"Distância da fábrica 01 para {row['co.cliente']}: {distancia_real1} km")
    else:
        print(f"Não foi possível calcular a distância para {row['Local']}")

#DISTANCIA REAL FÁBRICA 02:
for index, row in data.iterrows():
    coordenadas_clientes2 = (row['latitude'], row['longitude'])
    distancia_real2 = round(calculate_road_distance((lat_fabrica2, long_fabrica2), coordenadas_clientes2),2)
    if distancia_real2 is not None:
        print(f"Distância da fábrica 02 {row['co.cliente']}: {distancia_real2} km")
    else:
        print(f"Não foi possível calcular a distância para {row['Local']}")

#DISTANCIA REAL FÁBRICA 03:
for index, row in data.iterrows():
    coordenadas_clientes3 = (row['latitude'], row['longitude'])
    distancia_real3 = round(calculate_road_distance((lat_fabrica3, long_fabrica3), coordenadas_clientes3),2)
    if distancia_real3 is not None:
        print(f"Distância da fábrica 03 {row['co.cliente']}: {distancia_real3} km")
    else:
        print(f"Não foi possível calcular a distância para {row['Local']}")

# !pip install folium
import folium

#FÁBRICA01 ----------
mapa = folium.Map(location=[lat_fabrica1, long_fabrica1], zoom_start=12)

for index, row in data.iterrows():
    coordenadas_clientes1 = [row['latitude'], row['longitude']]
    distancia = calculate_road_distance((lat_fabrica1, long_fabrica1), coordenadas_clientes1)
    if distancia is not None:
        folium.Marker(location=coordenadas_clientes1, popup=f"{row['co.cliente']} ({distancia} km)").add_to(mapa)

folium.Marker(location=[lat_fabrica1, long_fabrica1], popup='Fabrica1', icon=folium.Icon(color='red')).add_to(mapa)

#FÁBRICA02 ----------
mapa = folium.Map(location=[lat_fabrica1, long_fabrica1], zoom_start=12)

for index, row in data.iterrows():
    coordenadas_clientes1 = [row['latitude'], row['longitude']]
    distancia = calculate_road_distance((lat_fabrica1, long_fabrica1), coordenadas_clientes1)
    if distancia is not None:
        folium.Marker(location=coordenadas_clientes1, popup=f"{row['co.cliente']} ({distancia} km)").add_to(mapa)

folium.Marker(location=[lat_fabrica1, long_fabrica1], popup='Fabrica1', icon=folium.Icon(color='red')).add_to(mapa)

#FÁBRICA03 ----------
mapa = folium.Map(location=[lat_fabrica1, long_fabrica1], zoom_start=12)

for index, row in data.iterrows():
    coordenadas_clientes1 = [row['latitude'], row['longitude']]
    distancia = calculate_road_distance((lat_fabrica1, long_fabrica1), coordenadas_clientes1)
    if distancia is not None:
        folium.Marker(location=coordenadas_clientes1, popup=f"{row['co.cliente']} ({distancia} km)").add_to(mapa)

folium.Marker(location=[lat_fabrica1, long_fabrica1], popup='Fabrica1', icon=folium.Icon(color='red')).add_to(mapa)

mapa.save("map.html")
mapa
# Out:
# Distância da fabrica para 2301: 46.39 km
# Distância da fabrica para 2302: 49.24 km
# Distância da fabrica para 2303: 47.65 km
# Distância da fabrica para 2304: 53.71 km
# Distância da fabrica para 2305: 54.73 km
# Distância da fabrica para 2306: 45.56 km
# Distância da fabrica para 2307: 42.22 km
# Distância da fabrica para 2308: 56.23 km
# Distância da fabrica para 2309: 58.75 km
# Distância da fabrica para 2310: 75.02 km
# Distância da fabrica para 2311: 62.4 km
# Distância da fabrica para 2312: 139.58 km
# Distância da fabrica para 2313: 147.2 km
# Distância da fabrica para 2314: 146.92 km
# Distância da fabrica para 2315: 148.12 km
# Distância da fabrica para 2316: 147.25 km
# Distância da fabrica para 2317: 146.64 km
# Distância da fabrica para 2318: 156.6 km
# Distância da fabrica para 2319: 74.84 km
# Distância da fabrica para 2320: 69.92 km
# Distância da fabrica para 2321: 70.43 km
# Distância da fabrica para 2322: 71.7 km
# Distância da fabrica para 2323: 72.26 km
# ...

# %%
#CÓDIGO FEITO UTILIZANDO OTIMIZAÇÃO DAS LINHAS - CÓDIGO REVISADO (02)
import pandas as pd
from geopy.distance import geodesic
import requests
import folium

# Dados dos clientes
clientes = [
    {'co.cliente': 2301, 'municipio': 'VALINHOS', 'latitude': -22.95188, 'longitude': -47.02779},
    {'co.cliente': 2302, 'municipio': 'CAMPINAS', 'latitude': -22.89429, 'longitude': -47.05822},
    {'co.cliente': 2303, 'municipio': 'CAMPINAS', 'latitude': -22.92634, 'longitude': -47.03974},
    {'co.cliente': 2304, 'municipio': 'CAMPINAS', 'latitude': -22.83309, 'longitude': -47.07943},
    {'co.cliente': 2305, 'municipio': 'CAMPINAS', 'latitude': -22.82307, 'longitude': -47.07818},
    {'co.cliente': 2306, 'municipio': 'VALINHOS', 'latitude': -22.97509, 'longitude': -47.01478},
    {'co.cliente': 2307, 'municipio': 'CAMPINAS', 'latitude': -22.94956, 'longitude': -47.09268},
    {'co.cliente': 2308, 'municipio': 'CAMPINAS', 'latitude': -22.88062, 'longitude': -46.96944},
    {'co.cliente': 2309, 'municipio': 'AMERICANA', 'latitude': -22.72237, 'longitude': -47.3074},
    {'co.cliente': 2310, 'municipio': 'SAO PAULO', 'latitude': -23.47084, 'longitude': -46.64965},
    {'co.cliente': 2311, 'municipio': 'PIRACICABA', 'latitude': -22.74145, 'longitude': -47.60181},
    {'co.cliente': 2312, 'municipio': 'JACAREI', 'latitude': -23.31105, 'longitude': -45.98107},
    {'co.cliente': 2313, 'municipio': 'SAO JOSE DOS CAMPOS', 'latitude': -23.
    {'co.cliente': 2342, 'municipio': 'CACAPAVA', 'latitude': -23.11919, 'longitude': -45.71347},
    {'co.cliente': 2343, 'municipio': 'PINDAMONHANGABA', 'latitude': -22.95467, 'longitude': -45.49489},
    {'co.cliente': 2344, 'municipio': 'SOROCABA', 'latitude': -23.46587, 'longitude': -47.49623},
    {'co.cliente': 2345, 'municipio': 'SOROCABA', 'latitude': -23.49563, 'longitude': -47.51121},
    {'co.cliente': 2346, 'municipio': 'SOROCABA', 'latitude': -23.48649, 'longitude': -47.47117},
    {'co.cliente': 2347, 'municipio': 'RIBEIRAO PRETO', 'latitude': -21.19498, 'longitude': -47.75589},
    {'co.cliente': 2348, 'municipio': 'RIBEIRAO PRETO', 'latitude': -21.14118, 'longitude': -47.80482},
    {'co.cliente': 2349, 'municipio': 'RIBEIRAO PRETO', 'latitude': -21.17516, 'longitude': -47.79455},
    {'co.cliente': 2350, 'municipio': 'BAURU', 'latitude': -22.3121, 'longitude': -49.05746},
    {'co.cliente': 2351, 'municipio': 'BAURU', 'latitude': -22.31628, 'longitude': -49.06815}
]
data = pd.DataFrame.from_dict(clientes)

# Dados das fábricas
fabricas = [
    {"codigo": "3423909", "latitude": -23.25178418, "longitude": -47.3439079},
    {"codigo": "3403208", "latitude": -21.82093539, "longitude": -48.17232722},
    {"codigo": "3424402", "latitude": -23.28713588, "longitude": -45.9849763},
]

# Função para calcular distância geodésica
def calcular_distancia_geodesica(coord_fabrica, coord_cliente):
    return round(geodesic(coord_fabrica, coord_cliente).kilometers, 2)

# Função para calcular a distância rodoviária usando API
def calcular_distancia_rodoviaria(origem, destino):
    url = "http://dev.virtualearth.net/REST/v1/Routes/DistanceMatrix"
    params = {
        "origins": f"{origem[0]},{origem[1]}",
        "destinations": f"{destino[0]},{destino[1]}",
        "travelMode": "driving",
        "key": "AmQ4bukp9WLfN9GqIntfn9pJugIvSSSfM7OxMxws5Up0F88YqlsXAA6IAPk6_vdI"
    }
    resposta = requests.get(url, params=params)
    data = resposta.json()
    if "resourceSets" in data and data["resourceSets"]:
        resultado = data["resourceSets"][0]["resources"]
        if resultado:
            return round(resultado[0]["results"][0]["travelDistance"], 2)
    return None

# Calcular e exibir distâncias
for fabrica in fabricas:
    coord_fabrica = (fabrica["latitude"], fabrica["longitude"])
    print(f"Distâncias para fábrica {fabrica['codigo']}:")
    for index, row in data.iterrows():
        coord_cliente = (row['latitude'], row['longitude'])
        distancia_geodesica = calcular_distancia_geodesica(coord_fabrica, coord_cliente)
        print(f"Cliente {row['co.cliente']}: {distancia_geodesica} km (geodésica)")

        distancia_rodoviaria = calcular_distancia_rodoviaria(coord_fabrica, coord_cliente)
        if distancia_rodoviaria is not None:
            print(f"Cliente {row['co.cliente']}: {distancia_rodoviaria} km (rodoviária)")
        else:
            print(f"Cliente {row['co.cliente']}: Não foi possível calcular a distância rodoviária")

# Visualização em mapa com Folium
mapa = folium.Map(location=[fabricas[0]["latitude"], fabricas[0]["longitude"]], zoom_start=8)

# Adiciona fábricas no mapa
for fabrica in fabricas:
    folium.Marker(
        location=[fabrica["latitude"], fabrica["longitude"]],
        popup=f"Fábrica {fabrica['codigo']}",
        icon=folium.Icon(color='red')
    ).add_to(mapa)

# Adiciona clientes no mapa
for index, row in data.iterrows():
    coord_cliente = [row['latitude'], row['longitude']]
    folium.Marker(
        location=coord_cliente,
        popup=f"Cliente {row['co.cliente']}",
        icon=folium.Icon(color='blue')
    ).add_to(mapa)

# Salva e exibe o mapa
mapa.save("map.html")
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#CÓDIGO PARA EXTRAIR OS DADOS PARA O ARQUIVO CSV - CÓDIGO REVISADO (03)
import pandas as pd
from geopy.distance import geodesic
import requests
import folium
from google.colab import files  # Para download automático no Colab

# Dados dos clientes
clientes = [
    {'co.cliente': 2301, 'municipio': 'VALINHOS', 'latitude': -22.95188, 'longitude': -47.02779},
    {'co.cliente': 2302, 'municipio': 'CAMPINAS', 'latitude': -22.89429, 'longitude': -47.05822},
    {'co.cliente': 2303, 'municipio': 'CAMPINAS', 'latitude': -22.92634, 'longitude': -47.03974},
    {'co.cliente': 2304, 'municipio': 'CAMPINAS', 'latitude': -22.83309, 'longitude': -47.07943},
    {'co.cliente': 2305, 'municipio': 'CAMPINAS', 'latitude': -22.82307, 'longitude': -47.07818},
    {'co.cliente': 2306, 'municipio': 'VALINHOS', 'latitude': -22.97509, 'longitude': -47.01478},
    {'co.cliente': 2307, 'municipio': 'CAMPINAS', 'latitude': -22.94956, 'longitude': -47.09268},
    {'co.cliente': 2308, 'municipio': 'CAMPINAS', 'latitude': -22.88062, 'longitude': -46.96944},
    {'co.cliente': 2309, 'municipio': 'AMERICANA', 'latitude': -22.72237, 'longitude': -47.3074},
    {'co.cliente': 2310, 'municipio': 'SAO PAULO', 'latitude': -23.47084, 'longitude': -46.64965},
    {'co.cliente': 2311, 'municipio': 'PIRACICABA', 'latitude': -22.74145, 'longitude': -47.60181},
    {'co.cliente': 2312, 'municipio': 'JACAREI', 'latitude': -23.31105, 'longitude': -45.98107},
    {'co.cliente': 2313, 'municipio': 'SAO JOSE DOS CAMPOS', 'latitude': -23.22299, 'longitude': -45.90595},
    {'co.cliente': 2314, 'municipio': 'SAO JOSE DOS CAMPOS', 'latitude': -23.22828, 'longitude': -45.90852},
    {'co.cliente': 2315, 'municipio': 'SAO JOSE DOS CAMPOS', 'latitude': -23.2374, 'longitude': -45.8966},
    {'co.cliente': 2316, 'municipio': 'SAO JOSE DOS CAMPOS', 'latitude': -23.24187, 'longitude': -45.905},
    {'co.cliente': 2317, 'municipio': 'SAO JOSE DOS CAMPOS', 'latitude': -23.22836, 'longitude': -45.91124},
    {'co.cliente': 2318, 'municipio': 'SAO JOSE DOS CAMPOS', 'latitude': -23.17422, 'longitude': -45.81629},
    {'co.cliente': 2319, 'municipio': 'SAO PAULO', 'latitude': -23.51672, 'longitude': -46.6704},
    {'co.cliente': 2320, 'municipio': 'SAO PAULO', 'latitude': -23.55224, 'longitude': -46.74232},
    {'co.cliente': 2321, 'municipio': 'SAO PAULO', 'latitude': -23.54149, 'longitude': -46.7306},
    {'co.cliente': 2322, 'municipio': 'SAO PAULO', 'latitude': -23.53466, 'longitude': -46.71295},
    {'co.cliente': 2323, 'municipio': 'SAO PAULO', 'latitude': -23.59032, 'longitude': -46.73951},
    {'co.cliente': 2324, 'municipio': 'SAO PAULO', 'latitude': -23.59551, 'longitude': -46.73765},
    {'co.cliente': 2325, 'municipio': 'SAO PAULO', 'latitude': -23.60962, 'longitude': -46.75296},
    {'co.cliente': 2326, 'municipio': 'COTIA', 'latitude': -23.58915, 'longitude': -46.8169},
    return round(geodesic(coord_fabrica, coord_cliente).kilometers, 2)

# Função para calcular a distância rodoviária usando API
def calcular_distancia_rodoviaria(origem, destino):
    url = "http://dev.virtualearth.net/REST/v1/Routes/DistanceMatrix"
    params = {
        "origins": f"{origem[0]},{origem[1]}",
        "destinations": f"{destino[0]},{destino[1]}",
        "travelMode": "driving",
        "key": "AmQ4bukp9WLfN9GqIntfn9pJugIvSSSfM7OxMxws5Up0F88YqlsXAA6IAPk6_vdI"
    }
    resposta = requests.get(url, params=params)
    data = resposta.json()
    if "resourceSets" in data and data["resourceSets"]:
        resultado = data["resourceSets"][0]["resources"]
        if resultado:
            return round(resultado[0]["results"][0]["travelDistance"], 2)
    return None

# Lista para armazenar as distâncias
distancias = []

# Calcular e exibir distâncias
for fabrica in fabricas:
    coord_fabrica = (fabrica["latitude"], fabrica["longitude"])
    for index, row in data.iterrows():
        coord_cliente = (row['latitude'], row['longitude'])
        distancia_geodesica = calcular_distancia_geodesica(coord_fabrica, coord_cliente)

        distancia_rodoviaria = calcular_distancia_rodoviaria(coord_fabrica, coord_cliente)

        # Adiciona os dados calculados na lista de distâncias
        distancias.append({
            "co.cliente": row["co.cliente"],
            "municipio": row["municipio"],
            "fabrica_codigo": fabrica["codigo"],
            "distancia_geodesica_km": distancia_geodesica,
            "distancia_rodoviaria_km": distancia_rodoviaria if distancia_rodoviaria is not None else "N/A"
        })

# Converte a lista de distâncias para DataFrame
df_distancias = pd.DataFrame(distancias)

# Verifica se todos os dados estão presentes no DataFrame
print(df_distancias)

# Salva o DataFrame em um arquivo CSV
df_distancias.to_csv("distancias_clientes_fabricas.csv", index=False, encoding="utf-8")

# Baixa automaticamente o CSV no Google Colab
files.download("distancias_clientes_fabricas.csv")

# Visualização em mapa com Folium
mapa = folium.Map(location=[fabricas[0]["latitude"], fabricas[0]["longitude"]], zoom_start=8)

# Adiciona fábricas no mapa
for fabrica in fabricas:
    folium.Marker(
        location=[fabrica["latitude"], fabrica["longitude"]],
        popup=f"Fábrica {fabrica['codigo']}",
        icon=folium.Icon(color='red')
    ).add_to(mapa)

# Adiciona clientes no mapa
for index, row in data.iterrows():
    coord_cliente = [row['latitude'], row['longitude']]
    folium.Marker(
        location=coord_cliente,
        popup=f"Cliente {row['co.cliente']} - {row['municipio']}",
        icon=folium.Icon(color='blue')
    ).add_to(mapa)

# Salva e exibe o mapa
mapa.save("map.html")
mapa
# Out:
#      co.cliente       municipio fabrica_codigo  distancia_geodesica_km  \
# 0          2301        VALINHOS        3423909                   46.39
# 1          2302        CAMPINAS        3423909                   49.24
# 2          2303        CAMPINAS        3423909                   47.65
# 3          2304        CAMPINAS        3423909                   53.71
# 4          2305        CAMPINAS        3423909                   54.73
# ..          ...             ...            ...                     ...
# 148        2347  RIBEIRAO PRETO        3424402                  294.95
# 149        2348  RIBEIRAO PRETO        3424402                  302.77
# 150        2349  RIBEIRAO PRETO        3424402                  299.15
# 151        2350           BAURU        3424402                  333.42
# 152        2351           BAURU        3424402                  334.30
#
#      distancia_rodoviaria_km
# 0                      59.41
# 1                      58.11
# ...
